# %% [markdown]
# # Feature Engineering for House Pricing (Part - 2)

# %% [markdown]
# ### We will be performing the below steps
# 1. Handling Missing Values
# 2. Temporal Variables
# 3. Handle Categorical Variables : Remove rare labels
# 4. Standardize the values of the variables to the same range

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# To Visualize all the columns in the dataframe
pd.pandas.set_option('display.max_columns',None)

# %%
dataset = pd.read_csv('train.csv') #House Price prediction dataset.
dataset.head() #First 5 records.
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
dataset.shape #Number of rows & Columns
# Out:
# (1460, 81)

# %%
X = dataset.drop(["Id","SalePrice"],axis=1) #Since Id feature is not neccessary so dropping it.
y = dataset["SalePrice"]

# %%
X = dataset.iloc[:,1:81] #Variable X is Independent feature
y = dataset.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

#(X_train Training dataset - Input feature), (X_test Validation data),
#(Y_train is Output features), (Y_test is Output features on Validation dataset)
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train #Train data is used for training our models
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1088         160       RM         24.0     2522   Pave   NaN      Reg
# 815           20       RL         48.0    12137   Pave   NaN      IR2
# 439           50       RL         67.0    12354   Pave  Grvl      Reg
# 919           20       RL         87.0    11029   Pave   NaN      IR1
# 518           60       RL          NaN     9531   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1016          20       RL         73.0    11883   Pave   NaN      Reg
# 829          160       FV         24.0     2544   Pave  Pave      Reg
# 345           50       RL         65.0     6435   Pave   NaN      Reg
# 771           20       RL         67.0     8877   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
X_test #Test data is used for verifying our models
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 448           50       RM         50.0     8600   Pave   NaN      Reg
# 1045          20       RL          NaN    13680   Pave   NaN      IR1
# 1241          20       RL         83.0     9849   Pave   NaN      Reg
# 544           60       RL         58.0    17104   Pave   NaN      IR1
# 1438          20       RM         90.0     7407   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 604           20       RL         88.0    12803   Pave   NaN      IR1
# 1148          50       RM          NaN     5700   Pave   NaN      Reg
# 1420          60       RL         90.0    11700   Pave   NaN      Reg
# 524           60       RL         95.0    11787   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
#Missing Values & % percentage

feature_nan = [feature for feature in dataset.columns if dataset[feature].isnull().sum() >= 1]

for feature in feature_nan:
    print("The feature is {} and missing values is {}%".format(feature, np.round(dataset[feature].isnull().mean()*100, 4)))
# Out:
# The feature is LotFrontage and missing values is 17.7397%
# The feature is Alley and missing values is 93.7671%
# The feature is MasVnrType and missing values is 0.5479%
# The feature is MasVnrArea and missing values is 0.5479%
# The feature is BsmtQual and missing values is 2.5342%
# The feature is BsmtCond and missing values is 2.5342%
# The feature is BsmtExposure and missing values is 2.6027%
# The feature is BsmtFinType1 and missing values is 2.5342%
# The feature is BsmtFinType2 and missing values is 2.6027%
# The feature is Electrical and missing values is 0.0685%
# The feature is FireplaceQu and missing values is 47.2603%
# The feature is GarageType and missing values is 5.5479%
# The feature is GarageYrBlt and missing values is 5.5479%
# The feature is GarageFinish and missing values is 5.5479%
# The feature is GarageQual and missing values is 5.5479%
# The feature is GarageCond and missing values is 5.5479%
# The feature is PoolQC and missing values is 99.5205%
# ...

# %%
## Replacing Categories features

Categorical_feature = [feature for feature in dataset.columns if dataset[feature].dtypes == 'O']
print(len(Categorical_feature))
Categorical_feature
# Out:
# 43
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
#Replacing NA values to Missing word in Categorical_Features
data = dataset.copy()
def replace_cat_features(dataset,Categorical_feature):
    data[Categorical_feature]=data[Categorical_feature].fillna("Missing")
    return data

# %%
replace_cat_features(data,Categorical_feature)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 0        1          60       RL         65.0     8450   Pave  Missing
# 1        2          20       RL         80.0     9600   Pave  Missing
# 2        3          60       RL         68.0    11250   Pave  Missing
# 3        4          70       RL         60.0     9550   Pave  Missing
# 4        5          60       RL         84.0    14260   Pave  Missing
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  Missing
# 1456  1457          20       RL         85.0    13175   Pave  Missing
# 1457  1458          70       RL         66.0     9042   Pave  Missing
# 1458  1459          20       RL         68.0     9717   Pave  Missing
# 1459  1460          20       RL         75.0     9937   Pave  Missing
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# ...

# %%
# Calculating mode for LotFrontage Feature
dataset['LotFrontage'].mode()
# Out:
# 0    60.0
# Name: LotFrontage, dtype: float64

# %%
data = dataset.copy()
def replace_cat_features(dataset,Categorical_feature):
    data[Categorical_feature]=data[Categorical_feature].fillna(data[Categorical_feature].mode())
    return data

# %%
replace_cat_features(data,Categorical_feature)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#Numerical features with null values
numerical_features_nan=[feature for feature in dataset.columns if dataset[feature].dtypes!='O' and dataset[feature].isnull().sum()>=1]

# %%
#Numrical Fatures with Nan Values
numerical_features_nan
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
for feature in numerical_features_nan:
    # Since there are outliers we are going to replace with median.
    median_values = dataset[feature].median()
    # Create a new feature to capture nan value
    dataset[feature+'nan']=np.where(dataset[feature].isnull(),1,0)
    dataset[feature].fillna(median_values,inplace=True)

# %%
dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
dataset['LotFrontage'].isnull().sum()
# Out:
# 0

# %%
#Temporal Variables (DateTime Variables)

for feature in ['YearBuilt', 'YearRemodAdd','GarageYrBlt']:
    dataset[feature+'age of house'] = dataset['YrSold'] - dataset[feature]

# %%
dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...
